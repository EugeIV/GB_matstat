# %% [markdown]
# #### Задача 1
# О непрерывной равномерно распределенной случайной величине $B$ известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины $B$ и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %% [markdown]
# По следующей формуле можно рассчитать дисперсию  $D(X)$:
# $$D(X) = \frac{(b - a)^2}{12}$$
# Дисперсия известна и равна $D(X) = 0.2$
#
# Левая граница известна и равна $a = 0.5$
#
# Следовательно правую границу $b$ можно вычислить по формуле:
# $$b = \sqrt{12\cdot{D(X)}} + a $$

# %%
import math

# %%
d_x = 0.2
a = 0.5
b = (math.sqrt(12 * d_x)) + a
print(round(b, 2))
# Out:
# 2.05

# %% [markdown]
# Среднее значене - это математическое ожидание, следовательно, воспользуемся формулой для математического ожидания равномерного распределения: $$ M(X) = \frac{(a + b)}{2} $$

# %%
m_x = (a + b) / 2
print(m_x)
# Out:
# 1.2745966692414834

# %% [markdown]
# #### Задача 2
# Рост взрослого населения города $X$ имеет нормальное распределение, причем, средний рост равен 174 см, а среднее квадратическое отклонение равно 8 см. посчитайте, какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# 1. больше 182 см?
# 2. больше 190 см?
# 3. от 166 см до 190 см?
# 4. от 166 см до 182 см?
# 5. от 158 см до 190 см?
# 6. не выше 150 см или не ниже 190 см?
# 7. не выше 150 см или не ниже 198 см?
# 8. ниже 166 см?
#
# Задачу можно решить двумя способами: без использования сторонних библиотек (numpy, scipy, pandas и пр.), а затем проверить себя с помощью встроенных функций

# %% [markdown]
# https://studopedia.ru/9_182249_normalnoe-raspredelenie.html
# https://matica.org.ua/metodichki-i-knigi-po-matematike/teoriia-veroiatnostei-praktikum-l-s-barkovskaia-l-v-stanishevskaia-iu-n-chertoritckii/8-8-normalnyi-zakon-raspredeleniia

# %% [markdown]
# Формула для нормального распределения:
# $$ f(x) = \frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x-a)^2}{2\sigma^2}} $$

# %% [markdown]
# где
# $$ a = M(X) = 174 $$
# $$ \sigma = 8 $$

# %%
f_182 = (1/(8*math.sqrt(2*math.pi)))*math.exp(-(math.pow(182-174, 2)/128))
print("f(182) =", f_182)
f_190 = (1/(8*math.sqrt(2*math.pi)))*math.exp(-(math.pow(190-174, 2)/128))
print("f(190) =", f_190)
f_166 = (1/(8*math.sqrt(2*math.pi)))*math.exp(-(math.pow(166-174, 2)/128))
print("f(166) =", f_166)
f_158 = (1/(8*math.sqrt(2*math.pi)))*math.exp(-(math.pow(158-174, 2)/128))
print("f(158) =", f_158)
f_150 = (1/(8*math.sqrt(2*math.pi)))*math.exp(-(math.pow(150-174, 2)/128))
print("f(150) =", f_150)
f_198 = (1/(8*math.sqrt(2*math.pi)))*math.exp(-(math.pow(198-174, 2)/128))
print("f(198) =", f_198)
# Out:
# f(182) = 0.03024634056489292
# f(190) = 0.006748870814148508
# f(166) = 0.03024634056489292
# f(158) = 0.006748870814148508
# f(150) = 0.0005539810514922509
# f(198) = 0.0005539810514922509

# %% [markdown]
# Вопрос: если данный ход мыслей правильный, то дальше нам необходимо найти вероятности, которые будут находится в интервалах роста? А они будут вычисляться как разницы между вероятностями. И сразу вопрос как проверить данные через библиотеки? Заранее спасибо за разъяснение.

# %% [markdown]
# #### Задача 3 (Дополнительно)
# Коробки с шоколадом упаковываются автоматически. Их средняя масса равна 1.06 кг. Известно, что 5% коробок имеют массу, меньшую 1 кг. Найдите:
# а) среднее квадратическое отклонение массы коробки,
# б) процент коробок, имеющих массу больше 1.1 кг.
#
# Подсказка.
# 1. Можно считать, что распределение массы коробки нормальное.
# 2. Найдите такое значение $scale$, для которого значение $cdf(x=1, loc=1.06, scale=scale)$ близко к 0.05. Точности 0.0001 будет достаточно.
