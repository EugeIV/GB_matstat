# %% [markdown]
# #### Задача 1
# Группа студентов изучает 10 различных дисциплин. Сколькими способами можно составить расписание на понедельник, если в этот день должно быть 4 разных занятия?

# %% [markdown]
# Определим число размещений из 10 дисциплин по 4 занятия в каждом.

# %%
from math import factorial

# %%
def arrangements(n, k):
    return int(factorial(n) / factorial(n - k))

# %%
print("Вариантов составления рассписания: ")
print(arrangements(10, 4))
# Out:
# Вариантов составления рассписания:
# 5040

# %% [markdown]
# #### Задача 2
# Из колоды в 52 карты вынимают случайным образом 4 карты. Найти число исходов, соответствующих тому, что был вытянут хотя бы один туз.

# %% [markdown]
# Для решения этой задачи будем использовать формулу сочетаний

# %%
from math import factorial

# %%
def combination(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# Рассмотрим сначала ситуацию, когда выбирается один туз из четырех

# %%
c1 = combination(4, 1)

# %% [markdown]
# Остальные три карты выбираются из 48 карт, тузы не рассматриваются, т.к. они уже выбраны.

# %%
c2 = combination(48, 3)

# %% [markdown]
# В таком случае число сочетаний, когда из колоды в 52 карты, выбрано 4 карты, одна из которых туз, будет равно

# %%
res = c1 * c2
print(res)
# Out:
# 69184

# %% [markdown]
# #### Задача 3
# Семь человек рассаживаются наудачу на скамейке. Какова вероятность того, что два определённых человека будут сидеть рядом?

# %% [markdown]
# Если я правильно понял задачу: то получается есть 6 возможных вариантов (условно обозначим это как 6 скамеек, т.к. каждая пара может сесть двумя способами, а остальные 5 человек любым способом на оставшиеся 5 скамеек, т.е.5!). Рассадить всех можно 7! способами.
# Получается можем использовать формулу для вероятности: P=m/n
# Число состоявшихся событий будет равно произведению возможных вариантов, а общее число испытаний 7!.

# %%
from math import factorial

# %%
P = (6*2*factorial(5)) / factorial(7)

# %%
print(P)
# Out:
# 0.2857142857142857

# %% [markdown]
# #### Задача 4
# Из 60 вопросов, входящих в экзаменационные билеты, студент знает 50. Какова вероятность того, что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?
